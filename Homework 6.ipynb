# %%
import pandas as pd

# %%
import math as mt

# %%
import numpy as np

# %%
import random

list_=[]
list_sum=[]
list_avg=[]
for j in range (100):
    for i in range(100):
        a = random.uniform(1,100)
        list_.append(a)
    sum_=math.fsum(list_)
    list_sum.append(sum_)
    avg_=np.mean(list_)
    list_avg.append(avg_)  
list_
print(list_sum)
print(list_avg)
# Out:
# [4706.597693618128, 9382.581178916771, 14577.916121763128, 19809.915386147328, 24851.10110610392, 29580.02701188024, 35148.273498718736, 39930.89182076246, 45431.53344235952, 50537.42756958307, 55594.785447741575, 60532.2696609789, 66038.62618720403, 70786.61892051659, 76086.74970087504, 80981.54208101603, 86427.27933421802, 92132.31557681698, 97151.7852744748, 102561.13200939247, 107496.0754771272, 112709.8561856944, 117516.57680583042, 122014.65923537486, 127234.12960890484, 132506.86967764876, 137792.82315950617, 143284.8923996081, 148153.45725656024, 153121.48490364585, 158377.90873856866, 162703.9280277696, 167830.80424464392, 173104.8615465122, 178026.05280277246, 182772.29347624417, 188761.11524170323, 193650.77940672412, 198823.79232512374, 203537.95248344628, 208742.98440517555, 214189.50107576748, 219078.27221605906, 224032.40279657053, 229383.3347494051, 234260.71379567886, 239050.10221199895, 244165.83708267112, 248663.7950510339, 253696.15718534682, 258500.2924643996, 26
# ...
