# %%
import pandas as pd

# %%
import math as mt

# %%
import numpy as np

# %%
import random

list_=[]
list_sum=[]
list_avg=[]
for j in range (100):
    for i in range(100):
        a = random.uniform(1,100)
        list_.append(a)
    sum_=mt.fsum(list_)
    list_sum.append(sum_)
    avg_=np.mean(list_)
    list_avg.append(avg_)  
list_
print(list_sum)
print(list_avg)
# Out:
# [5053.559231225719, 10145.223458936414, 15167.956700298242, 20296.441741651204, 25431.44248541017, 30328.238630568863, 35475.99075625585, 39949.83812243367, 45093.05587869324, 50522.187049122964, 55731.40556225385, 60594.62379811919, 65578.01565680497, 70889.74051312728, 75759.68709531095, 80689.38202519596, 85229.4976921016, 90587.65187913085, 95590.56103111431, 100780.69155477038, 105369.57964522665, 110450.7635887208, 115222.31914811362, 120464.0201921543, 126084.60425979183, 131004.03433534454, 136282.6449379748, 141048.85721566962, 146497.17353730032, 151531.8606302706, 156872.9141942296, 162004.0009057583, 167477.39167741084, 172842.93823390707, 178049.5831602436, 182977.6607545107, 187665.79131357552, 193373.45952242787, 198312.3312295874, 202799.02452243693, 208353.7937226295, 213197.27765048933, 218075.52453755084, 223127.33625336908, 228639.5554000043, 233841.64136322608, 239266.92668603102, 244468.28495786237, 249344.2777689463, 254420.054095188, 259103.30627501648, 264304
# ...
